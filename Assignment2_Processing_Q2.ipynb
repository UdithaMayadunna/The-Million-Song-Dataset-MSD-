# %%
# Run this cell to import pyspark and to define start_spark() and stop_spark()

import findspark

findspark.init()

import getpass
import pandas
import pyspark
import random
import re

from IPython.display import display, HTML
from pyspark import SparkContext
from pyspark.sql import SparkSession


# Functions used below

def username():
    """Get username with any domain information removed.
    """

    return re.sub('@.*', '', getpass.getuser())


def dict_to_html(d):
    """Convert a Python dictionary into a two column table for display.
    """

    html = []

    html.append(f'<table width="100%" style="width:100%; font-family: monospace;">')
    for k, v in d.items():
        html.append(f'<tr><td style="text-align:left;">{k}</td><td>{v}</td></tr>')
    html.append(f'</table>')

    return ''.join(html)


def show_as_html(df, n=20):
    """Leverage existing pandas jupyter integration to show a spark dataframe as html.
    
    Args:
        n (int): number of rows to show (default: 20)
    """

    display(df.limit(n).toPandas())

    
def display_spark():
    """Display the status of the active Spark session if one is currently running.
    """
    
    if 'spark' in globals() and 'sc' in globals():

        name = sc.getConf().get("spark.app.name")
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:green">active</span></b>, look for <code>{name}</code> under the running applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'<li><a href="{sc.uiWebUrl}" target="_blank">Spark Application UI</a></li>',
            f'</ul>',
            f'<p><b>Config</b></p>',
            dict_to_html(dict(sc.getConf().getAll())),
            f'<p><b>Notes</b></p>',
            f'<ul>',
            f'<li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li>',
            f'<li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>{name}</code> by hand using the link in the Spark UI.</li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))
        
    else:
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>{username() + " (jupyter)"}</code> is under the completed applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))


# Functions to start and stop spark

def start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1):
    """Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
    
    Args:
        executor_instances (int): number of executors (default: 2)
        executor_cores (int): number of cores per executor (default: 1)
        worker_memory (float): worker memory (default: 1)
        master_memory (float): master memory (default: 1)
    """

    global spark
    global sc

    user = username()
    
    cores = executor_instances * executor_cores
    partitions = cores * 4
    port = 4000 + random.randint(1, 999)

    spark = (
        SparkSession.builder
        .master("spark://masternode2:7077")
        .config("spark.driver.extraJavaOptions", f"-Dderby.system.home=/tmp/{user}/spark/")
        .config("spark.dynamicAllocation.enabled", "false")
        .config("spark.executor.instances", str(executor_instances))
        .config("spark.executor.cores", str(executor_cores))
        .config("spark.cores.max", str(cores))
        .config("spark.executor.memory", f"{worker_memory}g")
        .config("spark.driver.memory", f"{master_memory}g")
        .config("spark.driver.maxResultSize", "0")
        .config("spark.sql.shuffle.partitions", str(partitions))
        .config("spark.ui.port", str(port))
        .appName(user + " (jupyter)")
        .getOrCreate()
    )
    sc = SparkContext.getOrCreate()
    
    display_spark()

    
def stop_spark():
    """Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
    """

    global spark
    global sc

    if 'spark' in globals() and 'sc' in globals():

        spark.stop()

        del spark
        del sc

    display_spark()


# Make css changes to improve spark output readability

html = [
    '<style>',
    'pre { white-space: pre !important; }',
    'table.dataframe td { white-space: nowrap !important; }',
    'table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }',
    '</style>',
]
display(HTML(''.join(html)))
# Out:
# <style>pre { white-space: pre !important; }table.dataframe td { white-space: nowrap !important; }table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }</style>

# %%
# Run this cell to start a spark session in this notebook

start_spark(executor_instances=4, executor_cores=2, worker_memory=4, master_memory=4)
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:green">active</span></b>, look for <code>uwi14 (jupyter)</code> under the running applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li><li><a href="http://mathmadslinux2p.canterbury.ac.nz:4058" target="_blank">Spark Application UI</a></li></ul><p><b>Config</b></p><table width="100%" style="width:100%; font-family: monospace;"><tr><td style="text-align:left;">spark.dynamicAllocation.enabled</td><td>false</td></tr><tr><td style="text-align:left;">spark.executor.instances</td><td>4</td></tr><tr><td style="text-align:left;">spark.sql.warehouse.dir</td><td>file:/users/home/uwi14/Uditha/Assignment2/spark-warehouse</td></tr><tr><td style="text-align:left;">spark.driver.memory</td><td>4g</td></tr><tr><td style="text-align:left;">spark.driver.port</td><td>46645</td></tr><tr><td style="text-align:left;">spark.executor.memory</td><td>4g</td></tr><tr><td style="text-align:left;">spark.app.id</td><td>app-20240528201721-0312</td></tr><tr><td style="text-align:left;">spark.master</td><td>spark://masternode2:7077</td></tr><tr><td style="text-align:left;">spark.executor.id</td><td>driver</td></tr><tr><td style="text-align:left;">spark.executor.cores</td><td>2</td></tr><tr><td style="text-align:left;">spark.driver.host</td><td>mathmadslinux2p.canterbury.ac.nz</td></tr><tr><td style="text-align:left;">spark.ui.port</td><td>4058</td></tr><tr><td style="text-align:left;">spark.sql.shuffle.partitions</td><td>32</td></tr><tr><td style="text-align:left;">spark.app.name</td><td>uwi14 (jupyter)</td></tr><tr><td style="text-align:left;">spark.rdd.compress</td><td>True</td></tr><tr><td style="text-align:left;">spark.app.startTime</td><td>1716884239676</td></tr><tr><td style="text-align:left;">spark.serializer.objectStreamReset</td><td>100</td></tr><tr><td style="text-align:left;">spark.driver.maxResultSize</td><td>0</td></tr><tr><td style="text-align:left;">spark.cores.max</td><td>8</td></tr><tr><td style="text-align:left;">spark.submit.pyFiles</td><td></td></tr><tr><td style="text-align:left;">spark.submit.deployMode</td><td>client</td></tr><tr><td style="text-align:left;">spark.ui.showConsoleProgress</td><td>true</td></tr><tr><td style="text-align:left;">spark.driver.extraJavaOptions</td><td>-Dderby.system.home=/tmp/uwi14/spark/</td></tr></table><p><b>Notes</b></p><ul><li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li><li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>uwi14 (jupyter)</code> by hand using the link in the Spark UI.</li></ul>

# %%
# Write your imports and code here or insert cells below

from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
# Determine ideal number of partitions

conf = sc.getConf()

N = int(conf.get("spark.executor.instances"))
M = int(conf.get("spark.executor.cores"))
partitions = 4 * N * M

print(f'ideal # partitions = {partitions}')
# Out:
# ideal # partitions = 32

# %% [markdown]
# # Q2 - A

# %% [markdown]
# ### (a) Some of the tracks in the Million Song Dataset were matched to the wrong songs in the Taste Profile dataset and there is a list of song-track mismatches that were automatically identified and another list of mismatches that were manually accepted. Do we need to take any action to account for this based on the datasets that we are using in the sections below and how we are using them? Read the blog post mentioned above and think about if you need to match the datasets at all.

# %% [markdown]
# #### According to the Million Song's blog (Bertin-Mahieux, 2011), some tracks in the Million Song Dataset were matched to the wrong songs in the Taste Profile dataset. In the second part of the assignment, audio similarity was examined using one of the feature datasets and all music genre datasets. In the third part of the assignment, songs were recommended using the Taste Profile dataset. Therefore, in the second part, only track IDs were dealt with, and in the third part, only song IDs were addressed. Consequently, no action was needed regarding the mismatched songs, as song IDs and track IDs did not overlap throughout the assignment.

# %% [markdown]
# ### This is an example of removing the mismatched songs

# %%
#firstly, load the taste profile dataset
schema_triplets = StructType([
    StructField("user_id", StringType(), True),
    StructField("song_id",StringType(), True),
    StructField("play_count", IntegerType(), True)
])

# Load triplets data from HDFS
triplets = spark.read.csv("/data/msd/tasteprofile/triplets.tsv/", sep = '\t', schema = schema_triplets).repartition(partitions)
triplets.cache()

print('\n')
print(f'**Conclusion: The raw triplets table has {triplets.count()} rows.')
show_as_html(triplets, 5 )
# Out:
# **Conclusion: The raw triplets table has 48373586 rows.
#                                     user_id             song_id  play_count
# 0  afd3cb5fabe9685212317d5adf380ad40b29352c  SOMJIRK12A8C13D68D           1
# 1  49f6982f00e7b286cf068e03c04e97e909957841  SOIYWPZ12A81C204EF           1
# 2  e5a2ac098410c040ba03255fcc5c6a63a51c88e3  SOORDDG12A8AE461D0           1
# 3  2fab7f9fd56fdcf1131b50db78ac0eccf7fb8dab  SOXDLUF12AC4687779           9
# 4  85e83dd0e4158b49028882642a536246205624d9  SOJTLHS12A8C13F633           4

# %%
#load the mismatched information
sid_mismatches = spark.read.text("hdfs:///data/msd/tasteprofile/mismatches/sid_mismatches.txt").repartition(partitions)
sid_mismatches.head(5)
# Out:
# [Row(value='ERROR: <SOSHAHT12A8AE498DF TRGHCMN128F42422EB> Gene Kelly  -  Heavenly Music  !=  Summer Stock feat. MGM Studio Orchestra  -  Little Brown Jug [In The Good Old Summertime_ 1949]'),
#  Row(value="ERROR: <SOTVIGC12CF5F87EFA TRGLNBL128F9324F09>   -    !=  Lyfe Jennings  -  Let's Stay Together"),
#  Row(value='ERROR: <SOMIVVH12A58A7A4F3 TRBAYLZ128F933841B>   -    !=  Daryl Hall & John Oates  -  You Make My Dreams'),
#  Row(value='ERROR: <SOLPMEO12A8C136EC2 TRBWLFD128F4261A6A>   -    !=  Girl Talk  -  Friday Night'),
#  Row(value='ERROR: <SOCVMRY12A8AE486A6 TRGEDPP128F428AE71> Eurythmics  -  When Tomorrow Comes  !=  USAF Concert Band and Singing Sergeants  -  Variations on a West Country Carol')]

# %%
sid_mismatches = (sid_mismatches
                 .select(
                     F.substring(F.col('value'), 9,18).alias('song_id'),
                     F.substring(F.col('value'), 28,18).alias('track_id') ,
                     ))


sid_mismatches.printSchema()
show_as_html(sid_mismatches, 5)

print('\n')
print(f'The mismatches table has {sid_mismatches.count()} rows.')
# Out:
# root
#  |-- song_id: string (nullable = true)
#  |-- track_id: string (nullable = true)
#               song_id            track_id
# 0  SOSHAHT12A8AE498DF  TRGHCMN128F42422EB
# 1  SOTVIGC12CF5F87EFA  TRGLNBL128F9324F09
# 2  SOMIVVH12A58A7A4F3  TRBAYLZ128F933841B
# 3  SOLPMEO12A8C136EC2  TRBWLFD128F4261A6A
# 4  SOCVMRY12A8AE486A6  TRGEDPP128F428AE71
# The mismatches table has 19094 rows.

# %%
sid_matches_manually_accepted = spark.read.text('/data/msd/tasteprofile/mismatches/sid_matches_manually_accepted.txt')
sid_matches_manually_accepted.head(5)
# Out:
# [Row(value='9d8'),
#  Row(value='< ERROR: <SOFQHZM12A8C142342 TRMWMFG128F92FFEF2> Josipa Lisac  -  razloga  !=  Lisac Josipa  -  1000 razloga'),
#  Row(value='19d17'),
#  Row(value='< ERROR: <SODXUTF12AB018A3DA TRMWPCD12903CCE5ED> Lutan Fyah  -  Nuh Matter the Crisis Feat. Midnite  !=  Midnite  -  Nah Matter the Crisis'),
#  Row(value='29d26')]

# %%
sid_matches_manually_accepted.createOrReplaceTempView('sid_matches_manually_accepted_v')

sid_matches_manually_accepted = spark.sql(f"""select substr(value,11,18) as song_id
,substr(value,30,18) as track_id
from sid_matches_manually_accepted_v  
where value like '%ERROR%'          
          """)

# %%
sid_matches_manually_accepted.show(5)
print('\n')
print(f'The manually accepted mismatches {sid_matches_manually_accepted.count()} ')
# Out:
# +------------------+------------------+
# |           song_id|          track_id|
# +------------------+------------------+
# |SOFQHZM12A8C142342|TRMWMFG128F92FFEF2|
# |SODXUTF12AB018A3DA|TRMWPCD12903CCE5ED|
# |SOASCRF12A8C1372E6|TRMHIPJ128F426A2E2|
# |SOITDUN12A58A7AACA|TRMHXGK128F42446AB|
# |SOLZXUM12AB018BE39|TRMRSOF12903CCF516|
# +------------------+------------------+
# only showing top 5 rows
#
#
#
# The manually accepted mismatches 489

# %%
#deal with one situation: some matches are mistaken but manually accepted
sid_mismatches_outlier = sid_mismatches.join(
  sid_matches_manually_accepted,
  on = 'song_id',
  how="leftanti"
)

print(f'The raw count of mismatched song items: {sid_mismatches_outlier.count()}')
print(f'The new count of mismatched song items: {sid_mismatches.count()}')
print(f'There are {sid_mismatches.count() -sid_mismatches_outlier.count()} song items deleted.')
# Out:
# The raw count of mismatched song items: 19093
# The new count of mismatched song items: 19094
# There are 1 song items deleted.

# %%
triplets_new = triplets.join(
  sid_mismatches_outlier,
  on = 'song_id',
  how="leftanti"
)
print(f'The new row count of triplets: {triplets_2_removed.count()}.')
print(f'After {triplets.count() -triplets_new.count()} rows are deleted from Taste Profile Dataset.')
show_as_html(triplets_new, 5)
# Out:
# The new row count of triplets: 45795111.
# After 2578475 rows are deleted from Taste Profile Dataset.
#               song_id                                   user_id  play_count
# 0  SOMJIRK12A8C13D68D  afd3cb5fabe9685212317d5adf380ad40b29352c           1
# 1  SOIYWPZ12A81C204EF  49f6982f00e7b286cf068e03c04e97e909957841           1
# 2  SOORDDG12A8AE461D0  e5a2ac098410c040ba03255fcc5c6a63a51c88e3           1
# 3  SOXDLUF12AC4687779  2fab7f9fd56fdcf1131b50db78ac0eccf7fb8dab           9
# 4  SOJTLHS12A8C13F633  85e83dd0e4158b49028882642a536246205624d9           4

# %% [markdown]
# # Q2 - B

# %%
file_names = [
    "msd-jmir-area-of-moments-all-v1.0",
    "msd-jmir-lpc-all-v1.0",
    "msd-jmir-methods-of-moments-all-v1.0",
    "msd-jmir-mfcc-all-v1.0",
    "msd-jmir-spectral-all-all-v1.0",
    "msd-jmir-spectral-derivatives-all-all-v1.0",
    "msd-marsyas-timbral-v1.0",
    "msd-mvd-v1.0",
    "msd-rh-v1.0",
    "msd-rp-v1.0",
    "msd-ssd-v1.0",
    "msd-trh-v1.0",
    "msd-tssd-v1.0"
]

type_column_dic = {
    "real":DoubleType(),
    "NUMERIC":DoubleType(),
    "float":DoubleType(),
    "string":StringType(),
    "STRING":StringType()    
}

datasets = []

for name in file_names:    
    path_attributes = f'/data/msd/audio/attributes/{name}.attributes.csv'
    path_feature = f'/data/msd/audio/features/{name}.csv'
    
    attributes = spark.read.csv(path_attributes).toPandas()
        
    schema = StructType([
        StructField(column_name, type_column_dic[type_column_1], True) for i, (column_name, type_column_1) in attributes.iterrows()
    ])
    
    datasets.append((name, path_feature, schema))

# %%
#test one load
name, path_feature, schema = datasets[0]
id_name = schema[-1].name

# Load data    
data_0 = spark.read.csv(path_feature, schema = schema).repartition(partitions)
        
data_0 = data_0.withColumn(id_name, F.regexp_replace(F.col(id_name), "'", ""))

# Display
print(name)
print(data_0.count())
data_0.printSchema()
print(data_0.head())
show_as_html(data_0, 5)
# Out:
# msd-jmir-area-of-moments-all-v1.0
# 994623
# root
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_1: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_2: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_3: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_4: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_5: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_6: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_7: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_8: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_9: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Standard_Deviation_10: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_1: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_2: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_3: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_4: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_5: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_6: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_7: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_8: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_9: double (nullable = true)
#  |-- Area_Method_of_Moments_Overall_Average_10: double (nullable = true)
#  |-- MSD_TRACKID: string (nullable = true)
#
# Row(Area_Method_of_Moments_Overall_Standard_Deviation_1=0.5783, Area_Method_of_Moments_Overall_Standard_Deviation_2=6710.0, Area_Method_of_Moments_Overall_Standard_Deviation_3=46450.0, Area_Method_of_Moments_Overall_Standard_Deviation_4=160500000.0, Area_Method_of_Moments_Overall_Standard_Deviation_5=1117000000.0, Area_Method_of_Moments_Overall_Standard_Deviation_6=7775000000.0, Area_Method_of_Moments_Overall_Standard_Deviation_7=7076000000000.0, Area_Method_of_Moments_Overall_Standard_Deviation_8=10040000000.0, Area_Method_of_Moments_Overall_Standard_Deviation_9=69910000000.0, Area_Method_of_Moments_Overall_Standard_Deviation_10=2390000000000000.0, Area_Method_of_Moments_Overall_Average_1=2.863, Area_Method_of_Moments_Overall_Average_2=11580.0, Area_Method_of_Moments_Overall_Average_3=82680.0, Area_Method_of_Moments_Overall_Average_4=-179000000.0, Area_Method_of_Moments_Overall_Average_5=-1269000000.0, Area_Method_of_Moments_Overall_Average_6=-8986000000.0, Area_Method_of_Moments_Overall_Average_7=6230000000000.0, Area_Method_of_Moments_Overall_Average_8=11390000000.0, Area_Method_of_Moments_Overall_Average_9=80730000000.0, Area_Method_of_Moments_Overall_Average_10=2185000000000000.0, MSD_TRACKID='TRIZIUS128F4289B93')
#    Area_Method_of_Moments_Overall_Standard_Deviation_1  \
# 0                                            0.06341
# 1                                            1.01800
# 2                                            0.15570
# 3                                            0.80180
# 4                                            1.02600
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_2  \
# 0                                             3352.0
# 1                                             3357.0
# 2                                             3357.0
# 3                                             3354.0
# 4                                             6738.0
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_3  \
# 0                                             7133.0
# 1                                            19800.0
# 2                                             4951.0
# 3                                            27210.0
# 4                                            43210.0
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_4  \
# 0                                         39930000.0
# 1                                         39900000.0
# 2                                         40050000.0
# 3                                         39980000.0
# 4                                        161900000.0
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_5  \
# 0                                       8.764000e+07
# 1                                       2.350000e+08
# 2                                       5.889000e+07
# 3                                       3.284000e+08
# 4                                       1.051000e+09
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_6  \
# 0                                       1.920000e+08
# 1                                       1.383000e+09
# 2                                       8.643000e+07
# 3                                       2.697000e+09
# 4                                       6.819000e+09
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_7  \
# 0                                       8.777000e+11
# 1                                       8.762000e+11
# 2                                       8.819000e+11
# 3                                       8.796000e+11
# 4                                       7.173000e+12
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_8  \
# 0                                       7.840000e+08
# 1                                       2.105000e+09
# 2                                       5.282000e+08
# 3                                       2.937000e+09
# 4                                       9.478000e+09
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_9  \
# 0                                       1.720000e+09
# 1                                       1.240000e+10
# 2                                       7.765000e+08
# 3                                       2.414000e+10
# 4                                       6.151000e+10
#
#    Area_Method_of_Moments_Overall_Standard_Deviation_10         ...          \
# 0                                       9.373000e+12            ...
# 1                                       1.779000e+14            ...
# 2                                       2.793000e+12            ...
# 3                                       4.908000e+14            ...
# 4                                       1.969000e+15            ...
#
#    Area_Method_of_Moments_Overall_Average_2  \
# 0                                    5765.0
# 1                                    5747.0
# 2                                    5774.0
# 3                                    5770.0
# 4                                   11640.0
#
#    Area_Method_of_Moments_Overall_Average_3  \
# 0                                   13010.0
# 1                                   34040.0
# 2                                    8473.0
# 3                                   46060.0
# 4                                   78340.0
#
#    Area_Method_of_Moments_Overall_Average_4  \
# 0                               -44430000.0
# 1                               -44260000.0
# 2                               -44560000.0
# 3                               -44510000.0
# 4                              -180800000.0
#
#    Area_Method_of_Moments_Overall_Average_5  \
# 0                             -9.887000e+07
# 1                             -2.620000e+08
# 2                             -6.549000e+07
# 3                             -3.566000e+08
# 4                             -1.203000e+09
#
#    Area_Method_of_Moments_Overall_Average_6  \
# 0                             -2.195000e+08
# 1                             -1.548000e+09
# 2                             -9.597000e+07
# 3                             -2.856000e+09
# 4                             -7.996000e+09
#
#    Area_Method_of_Moments_Overall_Average_7  \
# 0                              7.711000e+11
# 1                              7.676000e+11
# 2                              7.744000e+11
# 3                              7.729000e+11
# 4                              6.321000e+12
#
#    Area_Method_of_Moments_Overall_Average_8  \
# 0                              8.821000e+08
# 1                              2.338000e+09
# 2                              5.860000e+08
# 3                              3.184000e+09
# 4                              1.084000e+10
#
#    Area_Method_of_Moments_Overall_Average_9  \
# 0                              1.963000e+09
# 1                              1.384000e+10
# 2                              8.612000e+08
# 3                              2.554000e+10
# 4                              7.213000e+10
#
#    Area_Method_of_Moments_Overall_Average_10         MSD_TRACKID
# 0                               8.358000e+12  TRVPMCC128F931FC22
# 1                               1.583000e+14  TRDGVLU128F14872A8
# 2                               2.451000e+12  TRDFROT128F9333EA6
# 3                               4.048000e+14  TRVJNAV128F4245695
# 4                               1.823000e+15  TRSJKZR128F92C4F9D
#
# [5 rows x 21 columns]

# %%
#test one load
name, path_feature, schema = datasets[9]
id_name = schema[-1].name

# Load data    
data_0 = spark.read.csv(path_feature, schema = schema).repartition(partitions)
        
data_0 = data_0.withColumn(id_name, F.regexp_replace(F.col(id_name), "'", ""))

# Display
print(name)
print(data_0.count())
data_0.printSchema()
print(data_0.head())
show_as_html(data_0, 5)
# Out:
# msd-rp-v1.0
# 994188
# root
#  |-- component_1: double (nullable = true)
#  |-- component_2: double (nullable = true)
#  |-- component_3: double (nullable = true)
#  |-- component_4: double (nullable = true)
#  |-- component_5: double (nullable = true)
#  |-- component_6: double (nullable = true)
#  |-- component_7: double (nullable = true)
#  |-- component_8: double (nullable = true)
#  |-- component_9: double (nullable = true)
#  |-- component_10: double (nullable = true)
#  |-- component_11: double (nullable = true)
#  |-- component_12: double (nullable = true)
#  |-- component_13: double (nullable = true)
#  |-- component_14: double (nullable = true)
#  |-- component_15: double (nullable = true)
#  |-- component_16: double (nullable = true)
#  |-- component_17: double (nullable = true)
#  |-- component_18: double (nullable = true)
#  |-- component_19: double (nullable = true)
#  |-- component_20: double (nullable = true)
#  |-- component_21: double (nullable = true)
#  |-- component_22: double (nullable = true)
#  |-- component_23: double (nullable = true)
#  |-- component_24: double (nullable = true)
#  |-- component_25: double (nullable = true)
#  |-- component_26: double (nullable = true)
#  |-- component_27: double (nullable = true)
#  |-- component_28: double (nullable = true)
#  |-- component_29: double (nullable = true)
#  |-- component_30: double (nullable = true)
#  |-- component_31: double (nullable = true)
#  |-- component_32: double (nullable = true)
#  |-- component_33: double (nullable = true)
#  |-- component_34: double (nullable = true)
#  |-- component_35: double (nullable = true)
#  |-- component_36: double (nullable = true)
#  |-- component_37: double (nullable = true)
#  |-- component_38: double (nullable = true)
#  |-- component_39: double (nullable = true)
#  |-- component_40: double (nullable = true)
#  |-- component_41: double (nullable = true)
#  |-- component_42: double (nullable = true)
#  |-- component_43: double (nullable = true)
#  |-- component_44: double (nullable = true)
#  |-- component_45: double (nullable = true)
#  |-- component_46: double (nullable = true)
#  |-- component_47: double (nullable = true)
#  |-- component_48: double (nullable = true)
#  |-- component_49: double (nullable = true)
#  |-- component_50: double (nullable = true)
#  |-- component_51: double (nullable = true)
#  |-- component_52: double (nullable = true)
#  |-- component_53: double (nullable = true)
#  |-- component_54: double (nullable = true)
#  |-- component_55: double (nullable = true)
#  |-- component_56: double (nullable = true)
#  |-- component_57: double (nullable = true)
#  |-- component_58: double (nullable = true)
#  |-- component_59: double (nullable = true)
#  |-- component_60: double (nullable = true)
#  |-- component_61: double (nullable = true)
#  |-- component_62: double (nullable = true)
#  |-- component_63: double (nullable = true)
#  |-- component_64: double (nullable = true)
#  |-- component_65: double (nullable = true)
#  |-- component_66: double (nullable = true)
#  |-- component_67: double (nullable = true)
#  |-- component_68: double (nullable = true)
#  |-- component_69: double (nullable = true)
#  |-- component_70: double (nullable = true)
#  |-- component_71: double (nullable = true)
#  |-- component_72: double (nullable = true)
#  |-- component_73: double (nullable = true)
#  |-- component_74: double (nullable = true)
#  |-- component_75: double (nullable = true)
#  |-- component_76: double (nullable = true)
#  |-- component_77: double (nullable = true)
#  |-- component_78: double (nullable = true)
#  |-- component_79: double (nullable = true)
#  |-- component_80: double (nullable = true)
#  |-- component_81: double (nullable = true)
#  |-- component_82: double (nullable = true)
#  |-- component_83: double (nullable = true)
#  |-- component_84: double (nullable = true)
#  |-- component_85: double (nullable = true)
#  |-- component_86: double (nullable = true)
#  |-- component_87: double (nullable = true)
#  |-- component_88: double (nullable = true)
#  |-- component_89: double (nullable = true)
#  |-- component_90: double (nullable = true)
#  |-- component_91: double (nullable = true)
#  |-- component_92: double (nullable = true)
#  |-- component_93: double (nullable = true)
#  |-- component_94: double (nullable = true)
#  |-- component_95: double (nullable = true)
#  |-- component_96: double (nullable = true)
#  |-- component_97: double (nullable = true)
#  |-- component_98: double (nullable = true)
#  |-- component_99: double (nullable = true)
#  |-- component_100: double (nullable = true)
#  |-- component_101: double (nullable = true)
#  |-- component_102: double (nullable = true)
#  |-- component_103: double (nullable = true)
#  |-- component_104: double (nullable = true)
#  |-- component_105: double (nullable = true)
#  |-- component_106: double (nullable = true)
#  |-- component_107: double (nullable = true)
#  |-- component_108: double (nullable = true)
#  |-- component_109: double (nullable = true)
#  |-- component_110: double (nullable = true)
#  |-- component_111: double (nullable = true)
#  |-- component_112: double (nullable = true)
#  |-- component_113: double (nullable = true)
#  |-- component_114: double (nullable = true)
#  |-- component_115: double (nullable = true)
#  |-- component_116: double (nullable = true)
#  |-- component_117: double (nullable = true)
#  |-- component_118: double (nullable = true)
#  |-- component_119: double (nullable = true)
#  |-- component_120: double (nullable = true)
#  |-- component_121: double (nullable = true)
#  |-- component_122: double (nullable = true)
#  |-- component_123: double (nullable = true)
#  |-- component_124: double (nullable = true)
#  |-- component_125: double (nullable = true)
#  |-- component_126: double (nullable = true)
#  |-- component_127: double (nullable = true)
#  |-- component_128: double (nullable = true)
#  |-- component_129: double (nullable = true)
#  |-- component_130: double (nullable = true)
#  |-- component_131: double (nullable = true)
#  |-- component_132: double (nullable = true)
#  |-- component_133: double (nullable = true)
#  |-- component_134: double (nullable = true)
#  |-- component_135: double (nullable = true)
#  |-- component_136: double (nullable = true)
#  |-- component_137: double (nullable = true)
#  |-- component_138: double (nullable = true)
#  |-- component_139: double (nullable = true)
#  |-- component_140: double (nullable = true)
#  |-- component_141: double (nullable = true)
#  |-- component_142: double (nullable = true)
#  |-- component_143: double (nullable = true)
#  |-- component_144: double (nullable = true)
#  |-- component_145: double (nullable = true)
#  |-- component_146: double (nullable = true)
#  |-- component_147: double (nullable = true)
#  |-- component_148: double (nullable = true)
#  |-- component_149: double (nullable = true)
#  |-- component_150: double (nullable = true)
#  |-- component_151: double (nullable = true)
#  |-- component_152: double (nullable = true)
#  |-- component_153: double (nullable = true)
#  |-- component_154: double (nullable = true)
#  |-- component_155: double (nullable = true)
#  |-- component_156: double (nullable = true)
#  |-- component_157: double (nullable = true)
#  |-- component_158: double (nullable = true)
#  |-- component_159: double (nullable = true)
#  |-- component_160: double (nullable = true)
#  |-- component_161: double (nullable = true)
#  |-- component_162: double (nullable = true)
#  |-- component_163: double (nullable = true)
#  |-- component_164: double (nullable = true)
#  |-- component_165: double (nullable = true)
#  |-- component_166: double (nullable = true)
#  |-- component_167: double (nullable = true)
#  |-- component_168: double (nullable = true)
#  |-- component_169: double (nullable = true)
#  |-- component_170: double (nullable = true)
#  |-- component_171: double (nullable = true)
#  |-- component_172: double (nullable = true)
#  |-- component_173: double (nullable = true)
#  |-- component_174: double (nullable = true)
#  |-- component_175: double (nullable = true)
#  |-- component_176: double (nullable = true)
#  |-- component_177: double (nullable = true)
#  |-- component_178: double (nullable = true)
#  |-- component_179: double (nullable = true)
#  |-- component_180: double (nullable = true)
#  |-- component_181: double (nullable = true)
#  |-- component_182: double (nullable = true)
#  |-- component_183: double (nullable = true)
#  |-- component_184: double (nullable = true)
#  |-- component_185: double (nullable = true)
#  |-- component_186: double (nullable = true)
#  |-- component_187: double (nullable = true)
#  |-- component_188: double (nullable = true)
#  |-- component_189: double (nullable = true)
#  |-- component_190: double (nullable = true)
#  |-- component_191: double (nullable = true)
#  |-- component_192: double (nullable = true)
#  |-- component_193: double (nullable = true)
#  |-- component_194: double (nullable = true)
#  |-- component_195: double (nullable = true)
#  |-- component_196: double (nullable = true)
#  |-- component_197: double (nullable = true)
#  |-- component_198: double (nullable = true)
#  |-- component_199: double (nullable = true)
#  |-- component_200: double (nullable = true)
#  |-- component_201: double (nullable = true)
#  |-- component_202: double (nullable = true)
#  |-- component_203: double (nullable = true)
#  |-- component_204: double (nullable = true)
#  |-- component_205: double (nullable = true)
#  |-- component_206: double (nullable = true)
#  |-- component_207: double (nullable = true)
#  |-- component_208: double (nullable = true)
#  |-- component_209: double (nullable = true)
#  |-- component_210: double (nullable = true)
#  |-- component_211: double (nullable = true)
#  |-- component_212: double (nullable = true)
#  |-- component_213: double (nullable = true)
#  |-- component_214: double (nullable = true)
#  |-- component_215: double (nullable = true)
#  |-- component_216: double (nullable = true)
#  |-- component_217: double (nullable = true)
#  |-- component_218: double (nullable = true)
#  |-- component_219: double (nullable = true)
#  |-- component_220: double (nullable = true)
#  |-- component_221: double (nullable = true)
#  |-- component_222: double (nullable = true)
#  |-- component_223: double (nullable = true)
#  |-- component_224: double (nullable = true)
#  |-- component_225: double (nullable = true)
#  |-- component_226: double (nullable = true)
#  |-- component_227: double (nullable = true)
#  |-- component_228: double (nullable = true)
#  |-- component_229: double (nullable = true)
#  |-- component_230: double (nullable = true)
#  |-- component_231: double (nullable = true)
#  |-- component_232: double (nullable = true)
#  |-- component_233: double (nullable = true)
#  |-- component_234: double (nullable = true)
#  |-- component_235: double (nullable = true)
#  |-- component_236: double (nullable = true)
#  |-- component_237: double (nullable = true)
#  |-- component_238: double (nullable = true)
#  |-- component_239: double (nullable = true)
#  |-- component_240: double (nullable = true)
#  |-- component_241: double (nullable = true)
#  |-- component_242: double (nullable = true)
#  |-- component_243: double (nullable = true)
#  |-- component_244: double (nullable = true)
#  |-- component_245: double (nullable = true)
#  |-- component_246: double (nullable = true)
#  |-- component_247: double (nullable = true)
#  |-- component_248: double (nullable = true)
#  |-- component_249: double (nullable = true)
#  |-- component_250: double (nullable = true)
#  |-- component_251: double (nullable = true)
#  |-- component_252: double (nullable = true)
#  |-- component_253: double (nullable = true)
#  |-- component_254: double (nullable = true)
#  |-- component_255: double (nullable = true)
#  |-- component_256: double (nullable = true)
#  |-- component_257: double (nullable = true)
#  |-- component_258: double (nullable = true)
#  |-- component_259: double (nullable = true)
#  |-- component_260: double (nullable = true)
#  |-- component_261: double (nullable = true)
#  |-- component_262: double (nullable = true)
#  |-- component_263: double (nullable = true)
#  |-- component_264: double (nullable = true)
#  |-- component_265: double (nullable = true)
#  |-- component_266: double (nullable = true)
#  |-- component_267: double (nullable = true)
#  |-- component_268: double (nullable = true)
#  |-- component_269: double (nullable = true)
#  |-- component_270: double (nullable = true)
#  |-- component_271: double (nullable = true)
#  |-- component_272: double (nullable = true)
#  |-- component_273: double (nullable = true)
#  |-- component_274: double (nullable = true)
#  |-- component_275: double (nullable = true)
#  |-- component_276: double (nullable = true)
#  |-- component_277: double (nullable = true)
#  |-- component_278: double (nullable = true)
#  |-- component_279: double (nullable = true)
#  |-- component_280: double (nullable = true)
#  |-- component_281: double (nullable = true)
#  |-- component_282: double (nullable = true)
#  |-- component_283: double (nullable = true)
#  |-- component_284: double (nullable = true)
#  |-- component_285: double (nullable = true)
#  |-- component_286: double (nullable = true)
#  |-- component_287: double (nullable = true)
#  |-- component_288: double (nullable = true)
#  |-- component_289: double (nullable = true)
#  |-- component_290: double (nullable = true)
#  |-- component_291: double (nullable = true)
#  |-- component_292: double (nullable = true)
#  |-- component_293: double (nullable = true)
#  |-- component_294: double (nullable = true)
#  |-- component_295: double (nullable = true)
#  |-- component_296: double (nullable = true)
#  |-- component_297: double (nullable = true)
#  |-- component_298: double (nullable = true)
#  |-- component_299: double (nullable = true)
#  |-- component_300: double (nullable = true)
#  |-- component_301: double (nullable = true)
#  |-- component_302: double (nullable = true)
#  |-- component_303: double (nullable = true)
#  |-- component_304: double (nullable = true)
#  |-- component_305: double (nullable = true)
#  |-- component_306: double (nullable = true)
#  |-- component_307: double (nullable = true)
#  |-- component_308: double (nullable = true)
#  |-- component_309: double (nullable = true)
#  |-- component_310: double (nullable = true)
#  |-- component_311: double (nullable = true)
#  |-- component_312: double (nullable = true)
#  |-- component_313: double (nullable = true)
#  |-- component_314: double (nullable = true)
#  |-- component_315: double (nullable = true)
#  |-- component_316: double (nullable = true)
#  |-- component_317: double (nullable = true)
#  |-- component_318: double (nullable = true)
#  |-- component_319: double (nullable = true)
#  |-- component_320: double (nullable = true)
#  |-- component_321: double (nullable = true)
#  |-- component_322: double (nullable = true)
#  |-- component_323: double (nullable = true)
#  |-- component_324: double (nullable = true)
#  |-- component_325: double (nullable = true)
#  |-- component_326: double (nullable = true)
#  |-- component_327: double (nullable = true)
#  |-- component_328: double (nullable = true)
#  |-- component_329: double (nullable = true)
#  |-- component_330: double (nullable = true)
#  |-- component_331: double (nullable = true)
#  |-- component_332: double (nullable = true)
#  |-- component_333: double (nullable = true)
#  |-- component_334: double (nullable = true)
#  |-- component_335: double (nullable = true)
#  |-- component_336: double (nullable = true)
#  |-- component_337: double (nullable = true)
#  |-- component_338: double (nullable = true)
#  |-- component_339: double (nullable = true)
#  |-- component_340: double (nullable = true)
#  |-- component_341: double (nullable = true)
#  |-- component_342: double (nullable = true)
#  |-- component_343: double (nullable = true)
#  |-- component_344: double (nullable = true)
#  |-- component_345: double (nullable = true)
#  |-- component_346: double (nullable = true)
#  |-- component_347: double (nullable = true)
#  |-- component_348: double (nullable = true)
#  |-- component_349: double (nullable = true)
#  |-- component_350: double (nullable = true)
#  |-- component_351: double (nullable = true)
#  |-- component_352: double (nullable = true)
#  |-- component_353: double (nullable = true)
#  |-- component_354: double (nullable = true)
#  |-- component_355: double (nullable = true)
#  |-- component_356: double (nullable = true)
#  |-- component_357: double (nullable = true)
#  |-- component_358: double (nullable = true)
#  |-- component_359: double (nullable = true)
#  |-- component_360: double (nullable = true)
#  |-- component_361: double (nullable = true)
#  |-- component_362: double (nullable = true)
#  |-- component_363: double (nullable = true)
#  |-- component_364: double (nullable = true)
#  |-- component_365: double (nullable = true)
#  |-- component_366: double (nullable = true)
#  |-- component_367: double (nullable = true)
#  |-- component_368: double (nullable = true)
#  |-- component_369: double (nullable = true)
#  |-- component_370: double (nullable = true)
#  |-- component_371: double (nullable = true)
#  |-- component_372: double (nullable = true)
#  |-- component_373: double (nullable = true)
#  |-- component_374: double (nullable = true)
#  |-- component_375: double (nullable = true)
#  |-- component_376: double (nullable = true)
#  |-- component_377: double (nullable = true)
#  |-- component_378: double (nullable = true)
#  |-- component_379: double (nullable = true)
#  |-- component_380: double (nullable = true)
#  |-- component_381: double (nullable = true)
#  |-- component_382: double (nullable = true)
#  |-- component_383: double (nullable = true)
#  |-- component_384: double (nullable = true)
#  |-- component_385: double (nullable = true)
#  |-- component_386: double (nullable = true)
#  |-- component_387: double (nullable = true)
#  |-- component_388: double (nullable = true)
#  |-- component_389: double (nullable = true)
#  |-- component_390: double (nullable = true)
#  |-- component_391: double (nullable = true)
#  |-- component_392: double (nullable = true)
#  |-- component_393: double (nullable = true)
#  |-- component_394: double (nullable = true)
#  |-- component_395: double (nullable = true)
#  |-- component_396: double (nullable = true)
#  |-- component_397: double (nullable = true)
#  |-- component_398: double (nullable = true)
#  |-- component_399: double (nullable = true)
#  |-- component_400: double (nullable = true)
#  |-- component_401: double (nullable = true)
#  |-- component_402: double (nullable = true)
#  |-- component_403: double (nullable = true)
#  |-- component_404: double (nullable = true)
#  |-- component_405: double (nullable = true)
#  |-- component_406: double (nullable = true)
#  |-- component_407: double (nullable = true)
#  |-- component_408: double (nullable = true)
#  |-- component_409: double (nullable = true)
#  |-- component_410: double (nullable = true)
#  |-- component_411: double (nullable = true)
#  |-- component_412: double (nullable = true)
#  |-- component_413: double (nullable = true)
#  |-- component_414: double (nullable = true)
#  |-- component_415: double (nullable = true)
#  |-- component_416: double (nullable = true)
#  |-- component_417: double (nullable = true)
#  |-- component_418: double (nullable = true)
#  |-- component_419: double (nullable = true)
#  |-- component_420: double (nullable = true)
#  |-- component_421: double (nullable = true)
#  |-- component_422: double (nullable = true)
#  |-- component_423: double (nullable = true)
#  |-- component_424: double (nullable = true)
#  |-- component_425: double (nullable = true)
#  |-- component_426: double (nullable = true)
#  |-- component_427: double (nullable = true)
#  |-- component_428: double (nullable = true)
#  |-- component_429: double (nullable = true)
#  |-- component_430: double (nullable = true)
#  |-- component_431: double (nullable = true)
#  |-- component_432: double (nullable = true)
#  |-- component_433: double (nullable = true)
#  |-- component_434: double (nullable = true)
#  |-- component_435: double (nullable = true)
#  |-- component_436: double (nullable = true)
#  |-- component_437: double (nullable = true)
#  |-- component_438: double (nullable = true)
#  |-- component_439: double (nullable = true)
#  |-- component_440: double (nullable = true)
#  |-- component_441: double (nullable = true)
#  |-- component_442: double (nullable = true)
#  |-- component_443: double (nullable = true)
#  |-- component_444: double (nullable = true)
#  |-- component_445: double (nullable = true)
#  |-- component_446: double (nullable = true)
#  |-- component_447: double (nullable = true)
#  |-- component_448: double (nullable = true)
#  |-- component_449: double (nullable = true)
#  |-- component_450: double (nullable = true)
#  |-- component_451: double (nullable = true)
#  |-- component_452: double (nullable = true)
#  |-- component_453: double (nullable = true)
#  |-- component_454: double (nullable = true)
#  |-- component_455: double (nullable = true)
#  |-- component_456: double (nullable = true)
#  |-- component_457: double (nullable = true)
#  |-- component_458: double (nullable = true)
#  |-- component_459: double (nullable = true)
#  |-- component_460: double (nullable = true)
#  |-- component_461: double (nullable = true)
#  |-- component_462: double (nullable = true)
#  |-- component_463: double (nullable = true)
#  |-- component_464: double (nullable = true)
#  |-- component_465: double (nullable = true)
#  |-- component_466: double (nullable = true)
#  |-- component_467: double (nullable = true)
#  |-- component_468: double (nullable = true)
#  |-- component_469: double (nullable = true)
#  |-- component_470: double (nullable = true)
#  |-- component_471: double (nullable = true)
#  |-- component_472: double (nullable = true)
#  |-- component_473: double (nullable = true)
#  |-- component_474: double (nullable = true)
#  |-- component_475: double (nullable = true)
#  |-- component_476: double (nullable = true)
#  |-- component_477: double (nullable = true)
#  |-- component_478: double (nullable = true)
#  |-- component_479: double (nullable = true)
#  |-- component_480: double (nullable = true)
#  |-- component_481: double (nullable = true)
#  |-- component_482: double (nullable = true)
#  |-- component_483: double (nullable = true)
#  |-- component_484: double (nullable = true)
#  |-- component_485: double (nullable = true)
#  |-- component_486: double (nullable = true)
#  |-- component_487: double (nullable = true)
#  |-- component_488: double (nullable = true)
#  |-- component_489: double (nullable = true)
#  |-- component_490: double (nullable = true)
#  |-- component_491: double (nullable = true)
#  |-- component_492: double (nullable = true)
#  |-- component_493: double (nullable = true)
#  |-- component_494: double (nullable = true)
#  |-- component_495: double (nullable = true)
#  |-- component_496: double (nullable = true)
#  |-- component_497: double (nullable = true)
#  |-- component_498: double (nullable = true)
#  |-- component_499: double (nullable = true)
#  |-- component_500: double (nullable = true)
#  |-- component_501: double (nullable = true)
#  |-- component_502: double (nullable = true)
#  |-- component_503: double (nullable = true)
#  |-- component_504: double (nullable = true)
#  |-- component_505: double (nullable = true)
#  |-- component_506: double (nullable = true)
#  |-- component_507: double (nullable = true)
#  |-- component_508: double (nullable = true)
#  |-- component_509: double (nullable = true)
#  |-- component_510: double (nullable = true)
#  |-- component_511: double (nullable = true)
#  |-- component_512: double (nullable = true)
#  |-- component_513: double (nullable = true)
#  |-- component_514: double (nullable = true)
#  |-- component_515: double (nullable = true)
#  |-- component_516: double (nullable = true)
#  |-- component_517: double (nullable = true)
#  |-- component_518: double (nullable = true)
#  |-- component_519: double (nullable = true)
#  |-- component_520: double (nullable = true)
#  |-- component_521: double (nullable = true)
#  |-- component_522: double (nullable = true)
#  |-- component_523: double (nullable = true)
#  |-- component_524: double (nullable = true)
#  |-- component_525: double (nullable = true)
#  |-- component_526: double (nullable = true)
#  |-- component_527: double (nullable = true)
#  |-- component_528: double (nullable = true)
#  |-- component_529: double (nullable = true)
#  |-- component_530: double (nullable = true)
#  |-- component_531: double (nullable = true)
#  |-- component_532: double (nullable = true)
#  |-- component_533: double (nullable = true)
#  |-- component_534: double (nullable = true)
#  |-- component_535: double (nullable = true)
#  |-- component_536: double (nullable = true)
#  |-- component_537: double (nullable = true)
#  |-- component_538: double (nullable = true)
#  |-- component_539: double (nullable = true)
#  |-- component_540: double (nullable = true)
#  |-- component_541: double (nullable = true)
#  |-- component_542: double (nullable = true)
#  |-- component_543: double (nullable = true)
#  |-- component_544: double (nullable = true)
#  |-- component_545: double (nullable = true)
#  |-- component_546: double (nullable = true)
#  |-- component_547: double (nullable = true)
#  |-- component_548: double (nullable = true)
#  |-- component_549: double (nullable = true)
#  |-- component_550: double (nullable = true)
#  |-- component_551: double (nullable = true)
#  |-- component_552: double (nullable = true)
#  |-- component_553: double (nullable = true)
#  |-- component_554: double (nullable = true)
#  |-- component_555: double (nullable = true)
#  |-- component_556: double (nullable = true)
#  |-- component_557: double (nullable = true)
#  |-- component_558: double (nullable = true)
#  |-- component_559: double (nullable = true)
#  |-- component_560: double (nullable = true)
#  |-- component_561: double (nullable = true)
#  |-- component_562: double (nullable = true)
#  |-- component_563: double (nullable = true)
#  |-- component_564: double (nullable = true)
#  |-- component_565: double (nullable = true)
#  |-- component_566: double (nullable = true)
#  |-- component_567: double (nullable = true)
#  |-- component_568: double (nullable = true)
#  |-- component_569: double (nullable = true)
#  |-- component_570: double (nullable = true)
#  |-- component_571: double (nullable = true)
#  |-- component_572: double (nullable = true)
#  |-- component_573: double (nullable = true)
#  |-- component_574: double (nullable = true)
#  |-- component_575: double (nullable = true)
#  |-- component_576: double (nullable = true)
#  |-- component_577: double (nullable = true)
#  |-- component_578: double (nullable = true)
#  |-- component_579: double (nullable = true)
#  |-- component_580: double (nullable = true)
#  |-- component_581: double (nullable = true)
#  |-- component_582: double (nullable = true)
#  |-- component_583: double (nullable = true)
#  |-- component_584: double (nullable = true)
#  |-- component_585: double (nullable = true)
#  |-- component_586: double (nullable = true)
#  |-- component_587: double (nullable = true)
#  |-- component_588: double (nullable = true)
#  |-- component_589: double (nullable = true)
#  |-- component_590: double (nullable = true)
#  |-- component_591: double (nullable = true)
#  |-- component_592: double (nullable = true)
#  |-- component_593: double (nullable = true)
#  |-- component_594: double (nullable = true)
#  |-- component_595: double (nullable = true)
#  |-- component_596: double (nullable = true)
#  |-- component_597: double (nullable = true)
#  |-- component_598: double (nullable = true)
#  |-- component_599: double (nullable = true)
#  |-- component_600: double (nullable = true)
#  |-- component_601: double (nullable = true)
#  |-- component_602: double (nullable = true)
#  |-- component_603: double (nullable = true)
#  |-- component_604: double (nullable = true)
#  |-- component_605: double (nullable = true)
#  |-- component_606: double (nullable = true)
#  |-- component_607: double (nullable = true)
#  |-- component_608: double (nullable = true)
#  |-- component_609: double (nullable = true)
#  |-- component_610: double (nullable = true)
#  |-- component_611: double (nullable = true)
#  |-- component_612: double (nullable = true)
#  |-- component_613: double (nullable = true)
#  |-- component_614: double (nullable = true)
#  |-- component_615: double (nullable = true)
#  |-- component_616: double (nullable = true)
#  |-- component_617: double (nullable = true)
#  |-- component_618: double (nullable = true)
#  |-- component_619: double (nullable = true)
#  |-- component_620: double (nullable = true)
#  |-- component_621: double (nullable = true)
#  |-- component_622: double (nullable = true)
#  |-- component_623: double (nullable = true)
#  |-- component_624: double (nullable = true)
#  |-- component_625: double (nullable = true)
#  |-- component_626: double (nullable = true)
#  |-- component_627: double (nullable = true)
#  |-- component_628: double (nullable = true)
#  |-- component_629: double (nullable = true)
#  |-- component_630: double (nullable = true)
#  |-- component_631: double (nullable = true)
#  |-- component_632: double (nullable = true)
#  |-- component_633: double (nullable = true)
#  |-- component_634: double (nullable = true)
#  |-- component_635: double (nullable = true)
#  |-- component_636: double (nullable = true)
#  |-- component_637: double (nullable = true)
#  |-- component_638: double (nullable = true)
#  |-- component_639: double (nullable = true)
#  |-- component_640: double (nullable = true)
#  |-- component_641: double (nullable = true)
#  |-- component_642: double (nullable = true)
#  |-- component_643: double (nullable = true)
#  |-- component_644: double (nullable = true)
#  |-- component_645: double (nullable = true)
#  |-- component_646: double (nullable = true)
#  |-- component_647: double (nullable = true)
#  |-- component_648: double (nullable = true)
#  |-- component_649: double (nullable = true)
#  |-- component_650: double (nullable = true)
#  |-- component_651: double (nullable = true)
#  |-- component_652: double (nullable = true)
#  |-- component_653: double (nullable = true)
#  |-- component_654: double (nullable = true)
#  |-- component_655: double (nullable = true)
#  |-- component_656: double (nullable = true)
#  |-- component_657: double (nullable = true)
#  |-- component_658: double (nullable = true)
#  |-- component_659: double (nullable = true)
#  |-- component_660: double (nullable = true)
#  |-- component_661: double (nullable = true)
#  |-- component_662: double (nullable = true)
#  |-- component_663: double (nullable = true)
#  |-- component_664: double (nullable = true)
#  |-- component_665: double (nullable = true)
#  |-- component_666: double (nullable = true)
#  |-- component_667: double (nullable = true)
#  |-- component_668: double (nullable = true)
#  |-- component_669: double (nullable = true)
#  |-- component_670: double (nullable = true)
#  |-- component_671: double (nullable = true)
#  |-- component_672: double (nullable = true)
#  |-- component_673: double (nullable = true)
#  |-- component_674: double (nullable = true)
#  |-- component_675: double (nullable = true)
#  |-- component_676: double (nullable = true)
#  |-- component_677: double (nullable = true)
#  |-- component_678: double (nullable = true)
#  |-- component_679: double (nullable = true)
#  |-- component_680: double (nullable = true)
#  |-- component_681: double (nullable = true)
#  |-- component_682: double (nullable = true)
#  |-- component_683: double (nullable = true)
#  |-- component_684: double (nullable = true)
#  |-- component_685: double (nullable = true)
#  |-- component_686: double (nullable = true)
#  |-- component_687: double (nullable = true)
#  |-- component_688: double (nullable = true)
#  |-- component_689: double (nullable = true)
#  |-- component_690: double (nullable = true)
#  |-- component_691: double (nullable = true)
#  |-- component_692: double (nullable = true)
#  |-- component_693: double (nullable = true)
#  |-- component_694: double (nullable = true)
#  |-- component_695: double (nullable = true)
#  |-- component_696: double (nullable = true)
#  |-- component_697: double (nullable = true)
#  |-- component_698: double (nullable = true)
#  |-- component_699: double (nullable = true)
#  |-- component_700: double (nullable = true)
#  |-- component_701: double (nullable = true)
#  |-- component_702: double (nullable = true)
#  |-- component_703: double (nullable = true)
#  |-- component_704: double (nullable = true)
#  |-- component_705: double (nullable = true)
#  |-- component_706: double (nullable = true)
#  |-- component_707: double (nullable = true)
#  |-- component_708: double (nullable = true)
#  |-- component_709: double (nullable = true)
#  |-- component_710: double (nullable = true)
#  |-- component_711: double (nullable = true)
#  |-- component_712: double (nullable = true)
#  |-- component_713: double (nullable = true)
#  |-- component_714: double (nullable = true)
#  |-- component_715: double (nullable = true)
#  |-- component_716: double (nullable = true)
#  |-- component_717: double (nullable = true)
#  |-- component_718: double (nullable = true)
#  |-- component_719: double (nullable = true)
#  |-- component_720: double (nullable = true)
#  |-- component_721: double (nullable = true)
#  |-- component_722: double (nullable = true)
#  |-- component_723: double (nullable = true)
#  |-- component_724: double (nullable = true)
#  |-- component_725: double (nullable = true)
#  |-- component_726: double (nullable = true)
#  |-- component_727: double (nullable = true)
#  |-- component_728: double (nullable = true)
#  |-- component_729: double (nullable = true)
#  |-- component_730: double (nullable = true)
#  |-- component_731: double (nullable = true)
#  |-- component_732: double (nullable = true)
#  |-- component_733: double (nullable = true)
#  |-- component_734: double (nullable = true)
#  |-- component_735: double (nullable = true)
#  |-- component_736: double (nullable = true)
#  |-- component_737: double (nullable = true)
#  |-- component_738: double (nullable = true)
#  |-- component_739: double (nullable = true)
#  |-- component_740: double (nullable = true)
#  |-- component_741: double (nullable = true)
#  |-- component_742: double (nullable = true)
#  |-- component_743: double (nullable = true)
#  |-- component_744: double (nullable = true)
#  |-- component_745: double (nullable = true)
#  |-- component_746: double (nullable = true)
#  |-- component_747: double (nullable = true)
#  |-- component_748: double (nullable = true)
#  |-- component_749: double (nullable = true)
#  |-- component_750: double (nullable = true)
#  |-- component_751: double (nullable = true)
#  |-- component_752: double (nullable = true)
#  |-- component_753: double (nullable = true)
#  |-- component_754: double (nullable = true)
#  |-- component_755: double (nullable = true)
#  |-- component_756: double (nullable = true)
#  |-- component_757: double (nullable = true)
#  |-- component_758: double (nullable = true)
#  |-- component_759: double (nullable = true)
#  |-- component_760: double (nullable = true)
#  |-- component_761: double (nullable = true)
#  |-- component_762: double (nullable = true)
#  |-- component_763: double (nullable = true)
#  |-- component_764: double (nullable = true)
#  |-- component_765: double (nullable = true)
#  |-- component_766: double (nullable = true)
#  |-- component_767: double (nullable = true)
#  |-- component_768: double (nullable = true)
#  |-- component_769: double (nullable = true)
#  |-- component_770: double (nullable = true)
#  |-- component_771: double (nullable = true)
#  |-- component_772: double (nullable = true)
#  |-- component_773: double (nullable = true)
#  |-- component_774: double (nullable = true)
#  |-- component_775: double (nullable = true)
#  |-- component_776: double (nullable = true)
#  |-- component_777: double (nullable = true)
#  |-- component_778: double (nullable = true)
#  |-- component_779: double (nullable = true)
#  |-- component_780: double (nullable = true)
#  |-- component_781: double (nullable = true)
#  |-- component_782: double (nullable = true)
#  |-- component_783: double (nullable = true)
#  |-- component_784: double (nullable = true)
#  |-- component_785: double (nullable = true)
#  |-- component_786: double (nullable = true)
#  |-- component_787: double (nullable = true)
#  |-- component_788: double (nullable = true)
#  |-- component_789: double (nullable = true)
#  |-- component_790: double (nullable = true)
#  |-- component_791: double (nullable = true)
#  |-- component_792: double (nullable = true)
#  |-- component_793: double (nullable = true)
#  |-- component_794: double (nullable = true)
#  |-- component_795: double (nullable = true)
#  |-- component_796: double (nullable = true)
#  |-- component_797: double (nullable = true)
#  |-- component_798: double (nullable = true)
#  |-- component_799: double (nullable = true)
#  |-- component_800: double (nullable = true)
#  |-- component_801: double (nullable = true)
#  |-- component_802: double (nullable = true)
#  |-- component_803: double (nullable = true)
#  |-- component_804: double (nullable = true)
#  |-- component_805: double (nullable = true)
#  |-- component_806: double (nullable = true)
#  |-- component_807: double (nullable = true)
#  |-- component_808: double (nullable = true)
#  |-- component_809: double (nullable = true)
#  |-- component_810: double (nullable = true)
#  |-- component_811: double (nullable = true)
#  |-- component_812: double (nullable = true)
#  |-- component_813: double (nullable = true)
#  |-- component_814: double (nullable = true)
#  |-- component_815: double (nullable = true)
#  |-- component_816: double (nullable = true)
#  |-- component_817: double (nullable = true)
#  |-- component_818: double (nullable = true)
#  |-- component_819: double (nullable = true)
#  |-- component_820: double (nullable = true)
#  |-- component_821: double (nullable = true)
#  |-- component_822: double (nullable = true)
#  |-- component_823: double (nullable = true)
#  |-- component_824: double (nullable = true)
#  |-- component_825: double (nullable = true)
#  |-- component_826: double (nullable = true)
#  |-- component_827: double (nullable = true)
#  |-- component_828: double (nullable = true)
#  |-- component_829: double (nullable = true)
#  |-- component_830: double (nullable = true)
#  |-- component_831: double (nullable = true)
#  |-- component_832: double (nullable = true)
#  |-- component_833: double (nullable = true)
#  |-- component_834: double (nullable = true)
#  |-- component_835: double (nullable = true)
#  |-- component_836: double (nullable = true)
#  |-- component_837: double (nullable = true)
#  |-- component_838: double (nullable = true)
#  |-- component_839: double (nullable = true)
#  |-- component_840: double (nullable = true)
#  |-- component_841: double (nullable = true)
#  |-- component_842: double (nullable = true)
#  |-- component_843: double (nullable = true)
#  |-- component_844: double (nullable = true)
#  |-- component_845: double (nullable = true)
#  |-- component_846: double (nullable = true)
#  |-- component_847: double (nullable = true)
#  |-- component_848: double (nullable = true)
#  |-- component_849: double (nullable = true)
#  |-- component_850: double (nullable = true)
#  |-- component_851: double (nullable = true)
#  |-- component_852: double (nullable = true)
#  |-- component_853: double (nullable = true)
#  |-- component_854: double (nullable = true)
#  |-- component_855: double (nullable = true)
#  |-- component_856: double (nullable = true)
#  |-- component_857: double (nullable = true)
#  |-- component_858: double (nullable = true)
#  |-- component_859: double (nullable = true)
#  |-- component_860: double (nullable = true)
#  |-- component_861: double (nullable = true)
#  |-- component_862: double (nullable = true)
#  |-- component_863: double (nullable = true)
#  |-- component_864: double (nullable = true)
#  |-- component_865: double (nullable = true)
#  |-- component_866: double (nullable = true)
#  |-- component_867: double (nullable = true)
#  |-- component_868: double (nullable = true)
#  |-- component_869: double (nullable = true)
#  |-- component_870: double (nullable = true)
#  |-- component_871: double (nullable = true)
#  |-- component_872: double (nullable = true)
#  |-- component_873: double (nullable = true)
#  |-- component_874: double (nullable = true)
#  |-- component_875: double (nullable = true)
#  |-- component_876: double (nullable = true)
#  |-- component_877: double (nullable = true)
#  |-- component_878: double (nullable = true)
#  |-- component_879: double (nullable = true)
#  |-- component_880: double (nullable = true)
#  |-- component_881: double (nullable = true)
#  |-- component_882: double (nullable = true)
#  |-- component_883: double (nullable = true)
#  |-- component_884: double (nullable = true)
#  |-- component_885: double (nullable = true)
#  |-- component_886: double (nullable = true)
#  |-- component_887: double (nullable = true)
#  |-- component_888: double (nullable = true)
#  |-- component_889: double (nullable = true)
#  |-- component_890: double (nullable = true)
#  |-- component_891: double (nullable = true)
#  |-- component_892: double (nullable = true)
#  |-- component_893: double (nullable = true)
#  |-- component_894: double (nullable = true)
#  |-- component_895: double (nullable = true)
#  |-- component_896: double (nullable = true)
#  |-- component_897: double (nullable = true)
#  |-- component_898: double (nullable = true)
#  |-- component_899: double (nullable = true)
#  |-- component_900: double (nullable = true)
#  |-- component_901: double (nullable = true)
#  |-- component_902: double (nullable = true)
#  |-- component_903: double (nullable = true)
#  |-- component_904: double (nullable = true)
#  |-- component_905: double (nullable = true)
#  |-- component_906: double (nullable = true)
#  |-- component_907: double (nullable = true)
#  |-- component_908: double (nullable = true)
#  |-- component_909: double (nullable = true)
#  |-- component_910: double (nullable = true)
#  |-- component_911: double (nullable = true)
#  |-- component_912: double (nullable = true)
#  |-- component_913: double (nullable = true)
#  |-- component_914: double (nullable = true)
#  |-- component_915: double (nullable = true)
#  |-- component_916: double (nullable = true)
#  |-- component_917: double (nullable = true)
#  |-- component_918: double (nullable = true)
#  |-- component_919: double (nullable = true)
#  |-- component_920: double (nullable = true)
#  |-- component_921: double (nullable = true)
#  |-- component_922: double (nullable = true)
#  |-- component_923: double (nullable = true)
#  |-- component_924: double (nullable = true)
#  |-- component_925: double (nullable = true)
#  |-- component_926: double (nullable = true)
#  |-- component_927: double (nullable = true)
#  |-- component_928: double (nullable = true)
#  |-- component_929: double (nullable = true)
#  |-- component_930: double (nullable = true)
#  |-- component_931: double (nullable = true)
#  |-- component_932: double (nullable = true)
#  |-- component_933: double (nullable = true)
#  |-- component_934: double (nullable = true)
#  |-- component_935: double (nullable = true)
#  |-- component_936: double (nullable = true)
#  |-- component_937: double (nullable = true)
#  |-- component_938: double (nullable = true)
#  |-- component_939: double (nullable = true)
#  |-- component_940: double (nullable = true)
#  |-- component_941: double (nullable = true)
#  |-- component_942: double (nullable = true)
#  |-- component_943: double (nullable = true)
#  |-- component_944: double (nullable = true)
#  |-- component_945: double (nullable = true)
#  |-- component_946: double (nullable = true)
#  |-- component_947: double (nullable = true)
#  |-- component_948: double (nullable = true)
#  |-- component_949: double (nullable = true)
#  |-- component_950: double (nullable = true)
#  |-- component_951: double (nullable = true)
#  |-- component_952: double (nullable = true)
#  |-- component_953: double (nullable = true)
#  |-- component_954: double (nullable = true)
#  |-- component_955: double (nullable = true)
#  |-- component_956: double (nullable = true)
#  |-- component_957: double (nullable = true)
#  |-- component_958: double (nullable = true)
#  |-- component_959: double (nullable = true)
#  |-- component_960: double (nullable = true)
#  |-- component_961: double (nullable = true)
#  |-- component_962: double (nullable = true)
#  |-- component_963: double (nullable = true)
#  |-- component_964: double (nullable = true)
#  |-- component_965: double (nullable = true)
#  |-- component_966: double (nullable = true)
#  |-- component_967: double (nullable = true)
#  |-- component_968: double (nullable = true)
#  |-- component_969: double (nullable = true)
#  |-- component_970: double (nullable = true)
#  |-- component_971: double (nullable = true)
#  |-- component_972: double (nullable = true)
#  |-- component_973: double (nullable = true)
#  |-- component_974: double (nullable = true)
#  |-- component_975: double (nullable = true)
#  |-- component_976: double (nullable = true)
#  |-- component_977: double (nullable = true)
#  |-- component_978: double (nullable = true)
#  |-- component_979: double (nullable = true)
#  |-- component_980: double (nullable = true)
#  |-- component_981: double (nullable = true)
#  |-- component_982: double (nullable = true)
#  |-- component_983: double (nullable = true)
#  |-- component_984: double (nullable = true)
#  |-- component_985: double (nullable = true)
#  |-- component_986: double (nullable = true)
#  |-- component_987: double (nullable = true)
#  |-- component_988: double (nullable = true)
#  |-- component_989: double (nullable = true)
#  |-- component_990: double (nullable = true)
#  |-- component_991: double (nullable = true)
#  |-- component_992: double (nullable = true)
#  |-- component_993: double (nullable = true)
#  |-- component_994: double (nullable = true)
#  |-- component_995: double (nullable = true)
#  |-- component_996: double (nullable = true)
#  |-- component_997: double (nullable = true)
#  |-- component_998: double (nullable = true)
#  |-- component_999: double (nullable = true)
#  |-- component_1000: double (nullable = true)
#  |-- component_1001: double (nullable = true)
#  |-- component_1002: double (nullable = true)
#  |-- component_1003: double (nullable = true)
#  |-- component_1004: double (nullable = true)
#  |-- component_1005: double (nullable = true)
#  |-- component_1006: double (nullable = true)
#  |-- component_1007: double (nullable = true)
#  |-- component_1008: double (nullable = true)
#  |-- component_1009: double (nullable = true)
#  |-- component_1010: double (nullable = true)
#  |-- component_1011: double (nullable = true)
#  |-- component_1012: double (nullable = true)
#  |-- component_1013: double (nullable = true)
#  |-- component_1014: double (nullable = true)
#  |-- component_1015: double (nullable = true)
#  |-- component_1016: double (nullable = true)
#  |-- component_1017: double (nullable = true)
#  |-- component_1018: double (nullable = true)
#  |-- component_1019: double (nullable = true)
#  |-- component_1020: double (nullable = true)
#  |-- component_1021: double (nullable = true)
#  |-- component_1022: double (nullable = true)
#  |-- component_1023: double (nullable = true)
#  |-- component_1024: double (nullable = true)
#  |-- component_1025: double (nullable = true)
#  |-- component_1026: double (nullable = true)
#  |-- component_1027: double (nullable = true)
#  |-- component_1028: double (nullable = true)
#  |-- component_1029: double (nullable = true)
#  |-- component_1030: double (nullable = true)
#  |-- component_1031: double (nullable = true)
#  |-- component_1032: double (nullable = true)
#  |-- component_1033: double (nullable = true)
#  |-- component_1034: double (nullable = true)
#  |-- component_1035: double (nullable = true)
#  |-- component_1036: double (nullable = true)
#  |-- component_1037: double (nullable = true)
#  |-- component_1038: double (nullable = true)
#  |-- component_1039: double (nullable = true)
#  |-- component_1040: double (nullable = true)
#  |-- component_1041: double (nullable = true)
#  |-- component_1042: double (nullable = true)
#  |-- component_1043: double (nullable = true)
#  |-- component_1044: double (nullable = true)
#  |-- component_1045: double (nullable = true)
#  |-- component_1046: double (nullable = true)
#  |-- component_1047: double (nullable = true)
#  |-- component_1048: double (nullable = true)
#  |-- component_1049: double (nullable = true)
#  |-- component_1050: double (nullable = true)
#  |-- component_1051: double (nullable = true)
#  |-- component_1052: double (nullable = true)
#  |-- component_1053: double (nullable = true)
#  |-- component_1054: double (nullable = true)
#  |-- component_1055: double (nullable = true)
#  |-- component_1056: double (nullable = true)
#  |-- component_1057: double (nullable = true)
#  |-- component_1058: double (nullable = true)
#  |-- component_1059: double (nullable = true)
#  |-- component_1060: double (nullable = true)
#  |-- component_1061: double (nullable = true)
#  |-- component_1062: double (nullable = true)
#  |-- component_1063: double (nullable = true)
#  |-- component_1064: double (nullable = true)
#  |-- component_1065: double (nullable = true)
#  |-- component_1066: double (nullable = true)
#  |-- component_1067: double (nullable = true)
# ...
#  |-- component_1227: double (nullable = true)
#  |-- component_1228: double (nullable = true)
#  |-- component_1229: double (nullable = true)
#  |-- component_1230: double (nullable = true)
#  |-- component_1231: double (nullable = true)
#  |-- component_1232: double (nullable = true)
#  |-- component_1233: double (nullable = true)
#  |-- component_1234: double (nullable = true)
#  |-- component_1235: double (nullable = true)
#  |-- component_1236: double (nullable = true)
#  |-- component_1237: double (nullable = true)
#  |-- component_1238: double (nullable = true)
#  |-- component_1239: double (nullable = true)
#  |-- component_1240: double (nullable = true)
#  |-- component_1241: double (nullable = true)
#  |-- component_1242: double (nullable = true)
#  |-- component_1243: double (nullable = true)
#  |-- component_1244: double (nullable = true)
#  |-- component_1245: double (nullable = true)
#  |-- component_1246: double (nullable = true)
#  |-- component_1247: double (nullable = true)
#  |-- component_1248: double (nullable = true)
#  |-- component_1249: double (nullable = true)
#  |-- component_1250: double (nullable = true)
#  |-- component_1251: double (nullable = true)
#  |-- component_1252: double (nullable = true)
#  |-- component_1253: double (nullable = true)
#  |-- component_1254: double (nullable = true)
#  |-- component_1255: double (nullable = true)
#  |-- component_1256: double (nullable = true)
#  |-- component_1257: double (nullable = true)
#  |-- component_1258: double (nullable = true)
#  |-- component_1259: double (nullable = true)
#  |-- component_1260: double (nullable = true)
#  |-- component_1261: double (nullable = true)
#  |-- component_1262: double (nullable = true)
#  |-- component_1263: double (nullable = true)
#  |-- component_1264: double (nullable = true)
#  |-- component_1265: double (nullable = true)
#  |-- component_1266: double (nullable = true)
#  |-- component_1267: double (nullable = true)
#  |-- component_1268: double (nullable = true)
#  |-- component_1269: double (nullable = true)
#  |-- component_1270: double (nullable = true)
#  |-- component_1271: double (nullable = true)
#  |-- component_1272: double (nullable = true)
#  |-- component_1273: double (nullable = true)
#  |-- component_1274: double (nullable = true)
#  |-- component_1275: double (nullable = true)
#  |-- component_1276: double (nullable = true)
#  |-- component_1277: double (nullable = true)
#  |-- component_1278: double (nullable = true)
#  |-- component_1279: double (nullable = true)
#  |-- component_1280: double (nullable = true)
#  |-- component_1281: double (nullable = true)
#  |-- component_1282: double (nullable = true)
#  |-- component_1283: double (nullable = true)
#  |-- component_1284: double (nullable = true)
#  |-- component_1285: double (nullable = true)
#  |-- component_1286: double (nullable = true)
#  |-- component_1287: double (nullable = true)
#  |-- component_1288: double (nullable = true)
#  |-- component_1289: double (nullable = true)
#  |-- component_1290: double (nullable = true)
#  |-- component_1291: double (nullable = true)
#  |-- component_1292: double (nullable = true)
#  |-- component_1293: double (nullable = true)
#  |-- component_1294: double (nullable = true)
#  |-- component_1295: double (nullable = true)
#  |-- component_1296: double (nullable = true)
#  |-- component_1297: double (nullable = true)
#  |-- component_1298: double (nullable = true)
#  |-- component_1299: double (nullable = true)
#  |-- component_1300: double (nullable = true)
#  |-- component_1301: double (nullable = true)
#  |-- component_1302: double (nullable = true)
#  |-- component_1303: double (nullable = true)
#  |-- component_1304: double (nullable = true)
#  |-- component_1305: double (nullable = true)
#  |-- component_1306: double (nullable = true)
#  |-- component_1307: double (nullable = true)
#  |-- component_1308: double (nullable = true)
#  |-- component_1309: double (nullable = true)
#  |-- component_1310: double (nullable = true)
#  |-- component_1311: double (nullable = true)
#  |-- component_1312: double (nullable = true)
#  |-- component_1313: double (nullable = true)
#  |-- component_1314: double (nullable = true)
#  |-- component_1315: double (nullable = true)
#  |-- component_1316: double (nullable = true)
#  |-- component_1317: double (nullable = true)
#  |-- component_1318: double (nullable = true)
#  |-- component_1319: double (nullable = true)
#  |-- component_1320: double (nullable = true)
#  |-- component_1321: double (nullable = true)
#  |-- component_1322: double (nullable = true)
#  |-- component_1323: double (nullable = true)
#  |-- component_1324: double (nullable = true)
#  |-- component_1325: double (nullable = true)
#  |-- component_1326: double (nullable = true)
#  |-- component_1327: double (nullable = true)
#  |-- component_1328: double (nullable = true)
#  |-- component_1329: double (nullable = true)
#  |-- component_1330: double (nullable = true)
#  |-- component_1331: double (nullable = true)
#  |-- component_1332: double (nullable = true)
#  |-- component_1333: double (nullable = true)
#  |-- component_1334: double (nullable = true)
#  |-- component_1335: double (nullable = true)
#  |-- component_1336: double (nullable = true)
#  |-- component_1337: double (nullable = true)
#  |-- component_1338: double (nullable = true)
#  |-- component_1339: double (nullable = true)
#  |-- component_1340: double (nullable = true)
#  |-- component_1341: double (nullable = true)
#  |-- component_1342: double (nullable = true)
#  |-- component_1343: double (nullable = true)
#  |-- component_1344: double (nullable = true)
#  |-- component_1345: double (nullable = true)
#  |-- component_1346: double (nullable = true)
#  |-- component_1347: double (nullable = true)
#  |-- component_1348: double (nullable = true)
#  |-- component_1349: double (nullable = true)
#  |-- component_1350: double (nullable = true)
#  |-- component_1351: double (nullable = true)
#  |-- component_1352: double (nullable = true)
#  |-- component_1353: double (nullable = true)
#  |-- component_1354: double (nullable = true)
#  |-- component_1355: double (nullable = true)
#  |-- component_1356: double (nullable = true)
#  |-- component_1357: double (nullable = true)
#  |-- component_1358: double (nullable = true)
#  |-- component_1359: double (nullable = true)
#  |-- component_1360: double (nullable = true)
#  |-- component_1361: double (nullable = true)
#  |-- component_1362: double (nullable = true)
#  |-- component_1363: double (nullable = true)
#  |-- component_1364: double (nullable = true)
#  |-- component_1365: double (nullable = true)
#  |-- component_1366: double (nullable = true)
#  |-- component_1367: double (nullable = true)
#  |-- component_1368: double (nullable = true)
#  |-- component_1369: double (nullable = true)
#  |-- component_1370: double (nullable = true)
#  |-- component_1371: double (nullable = true)
#  |-- component_1372: double (nullable = true)
#  |-- component_1373: double (nullable = true)
#  |-- component_1374: double (nullable = true)
#  |-- component_1375: double (nullable = true)
#  |-- component_1376: double (nullable = true)
#  |-- component_1377: double (nullable = true)
#  |-- component_1378: double (nullable = true)
#  |-- component_1379: double (nullable = true)
#  |-- component_1380: double (nullable = true)
#  |-- component_1381: double (nullable = true)
#  |-- component_1382: double (nullable = true)
#  |-- component_1383: double (nullable = true)
#  |-- component_1384: double (nullable = true)
#  |-- component_1385: double (nullable = true)
#  |-- component_1386: double (nullable = true)
#  |-- component_1387: double (nullable = true)
#  |-- component_1388: double (nullable = true)
#  |-- component_1389: double (nullable = true)
#  |-- component_1390: double (nullable = true)
#  |-- component_1391: double (nullable = true)
#  |-- component_1392: double (nullable = true)
#  |-- component_1393: double (nullable = true)
#  |-- component_1394: double (nullable = true)
#  |-- component_1395: double (nullable = true)
#  |-- component_1396: double (nullable = true)
#  |-- component_1397: double (nullable = true)
#  |-- component_1398: double (nullable = true)
#  |-- component_1399: double (nullable = true)
#  |-- component_1400: double (nullable = true)
#  |-- component_1401: double (nullable = true)
#  |-- component_1402: double (nullable = true)
#  |-- component_1403: double (nullable = true)
#  |-- component_1404: double (nullable = true)
#  |-- component_1405: double (nullable = true)
#  |-- component_1406: double (nullable = true)
#  |-- component_1407: double (nullable = true)
#  |-- component_1408: double (nullable = true)
#  |-- component_1409: double (nullable = true)
#  |-- component_1410: double (nullable = true)
#  |-- component_1411: double (nullable = true)
#  |-- component_1412: double (nullable = true)
#  |-- component_1413: double (nullable = true)
#  |-- component_1414: double (nullable = true)
#  |-- component_1415: double (nullable = true)
#  |-- component_1416: double (nullable = true)
#  |-- component_1417: double (nullable = true)
#  |-- component_1418: double (nullable = true)
#  |-- component_1419: double (nullable = true)
#  |-- component_1420: double (nullable = true)
#  |-- component_1421: double (nullable = true)
#  |-- component_1422: double (nullable = true)
#  |-- component_1423: double (nullable = true)
#  |-- component_1424: double (nullable = true)
#  |-- component_1425: double (nullable = true)
#  |-- component_1426: double (nullable = true)
#  |-- component_1427: double (nullable = true)
#  |-- component_1428: double (nullable = true)
#  |-- component_1429: double (nullable = true)
#  |-- component_1430: double (nullable = true)
#  |-- component_1431: double (nullable = true)
#  |-- component_1432: double (nullable = true)
#  |-- component_1433: double (nullable = true)
#  |-- component_1434: double (nullable = true)
#  |-- component_1435: double (nullable = true)
#  |-- component_1436: double (nullable = true)
#  |-- component_1437: double (nullable = true)
#  |-- component_1438: double (nullable = true)
#  |-- component_1439: double (nullable = true)
#  |-- component_1440: double (nullable = true)
#  |-- instanceName: string (nullable = true)
# Row(component_1=0.000732, component_2=0.004374, component_3=0.010033, component_4=0.021959, component_5=0.021077, component_6=0.021095, component_7=0.010749, component_8=0.0085, component_9=0.005567, component_10=0.011657, component_11=0.013513, component_12=0.017738, component_13=0.008703, component_14=0.010784, component_15=0.016256, component_16=0.026867, component_17=0.016416, component_18=0.022224, component_19=0.006332, component_20=0.006577, component_21=0.003075, component_22=0.003139, component_23=0.003051, component_24=0.0, component_25=0.013235, component_26=0.023563, component_27=0.026978, component_28=0.054015, component_29=0.013446, component_30=0.052847, component_31=0.049181, component_32=0.026644, component_33=0.018725, component_34=0.023462, component_35=0.076165, component_36=0.041573, component_37=0.027638, component_38=0.018374, component_39=0.015748, component_40=0.032476, component_41=0.028952, component_42=0.032233, component_43=0.00894, component_44=0.016605, component_45=0.00958, component_46=0.005934, component_47=0.002085, component_48=0.0, component_49=0.018348, component_50=0.008364, component_51=0.032562, component_52=0.069972, component_53=0.01214, component_54=0.085076, component_55=0.058029, component_56=0.021661, component_57=0.01989, component_58=0.015055, component_59=0.032404, component_60=0.032507, component_61=0.045745, component_62=0.027637, component_63=0.038312, component_64=0.012812, component_65=0.029537, component_66=0.036149, component_67=0.018225, component_68=0.00869, component_69=0.011408, component_70=0.006182, component_71=0.005211, component_72=1e-06, component_73=0.024969, component_74=0.018655, component_75=0.041145, component_76=0.02591, component_77=0.010607, component_78=0.146848, component_79=0.08845, component_80=0.087908, component_81=0.126408, component_82=0.083933, component_83=0.106293, component_84=0.063869, component_85=0.051264, component_86=0.05794, component_87=0.071374, component_88=0.047177, component_89=0.051339, component_90=0.077742, component_91=0.01682, component_92=0.01096, component_93=0.006297, component_94=0.020221, component_95=0.012333, component_96=1e-06, component_97=0.050583, component_98=0.066963, component_99=0.067361, component_100=0.118373, component_101=0.024079, component_102=0.120194, component_103=0.129951, component_104=0.115438, component_105=0.150307, component_106=0.128947, component_107=0.205844, component_108=0.068399, component_109=0.037528, component_110=0.041484, component_111=0.048801, component_112=0.077286, component_113=0.072709, component_114=0.070588, component_115=0.030866, component_116=0.016648, component_117=0.012718, component_118=0.027858, component_119=0.02064, component_120=1e-06, component_121=0.023723, component_122=0.014092, component_123=0.0301, component_124=0.080958, component_125=0.051439, component_126=0.221244, component_127=0.064274, component_128=0.098341, component_129=0.129751, component_130=0.104519, component_131=0.134341, component_132=0.077164, component_133=0.04948, component_134=0.043369, component_135=0.021929, component_136=0.057649, component_137=0.039884, component_138=0.082254, component_139=0.034696, component_140=0.012847, component_141=0.004525, component_142=0.014067, component_143=0.005592, component_144=1e-06, component_145=0.050973, component_146=0.053544, component_147=0.058456, component_148=0.095267, component_149=0.061391, component_150=0.098121, component_151=0.112486, component_152=0.076848, component_153=0.121009, component_154=0.078084, component_155=0.083412, component_156=0.108921, component_157=0.082826, component_158=0.029611, component_159=0.059813, component_160=0.07661, component_161=0.036487, component_162=0.070456, component_163=0.05158, component_164=0.014447, component_165=0.005238, component_166=0.042676, component_167=0.026697, component_168=1e-06, component_169=0.020378, component_170=0.019636, component_171=0.050161, component_172=0.167856, component_173=0.030 ...
#    component_1  component_2  component_3  component_4  component_5  \
# 0     0.012820     0.025459     0.030069     0.014544     0.028225
# 1     0.016309     0.008060     0.031449     0.017469     0.012181
# 2     0.042403     0.024452     0.014649     0.011565     0.013444
# 3     0.004917     0.025960     0.006874     0.025598     0.007810
# 4     0.025119     0.032041     0.024421     0.011334     0.026388
#
#    component_6  component_7  component_8  component_9  component_10  \
# 0     0.041932     0.031324     0.027404     0.026318      0.013191
# 1     0.017402     0.017052     0.013064     0.010149      0.009149
# 2     0.013876     0.003947     0.004569     0.006740      0.004830
# 3     0.007205     0.006379     0.009370     0.011978      0.005840
# 4     0.022804     0.026802     0.019875     0.046378      0.034768
#
#           ...          component_1432  component_1433  component_1434  \
# 0         ...                0.024848        0.047171        0.059207
# 1         ...                0.081111        0.056194        0.080337
# 2         ...                0.013483        0.014493        0.013235
# 3         ...                0.004380        0.003503        0.002986
# 4         ...                0.059956        0.055016        0.047135
#
#    component_1435  component_1436  component_1437  component_1438  \
# 0        0.021858        0.026521        0.020713        0.020222
# 1        0.054890        0.038141        0.033667        0.024478
# 2        0.014287        0.012159        0.008529        0.011702
# 3        0.001669        0.001513        0.000916        0.000678
# 4        0.047023        0.038177        0.037378        0.034569
#
#    component_1439  component_1440        instanceName
# 0        0.011010        0.003796  TRLIWTJ128F428C2B2
# 1        0.009277        0.000001  TRYGEZW128F147DB6A
# 2        0.005376        0.000001  TRBDKAN12903CBF568
# 3        0.000008        0.000001  TRWCGAH128F428E276
# 4        0.014963        0.000001  TRMCQJG128F42A2716
#
# [5 rows x 1441 columns]

# %%
for name in file_names:

    metadata_schema = StructType([
        StructField("name", StringType()),
        StructField("type", StringType()),
    ])
    metadata = spark.read.csv(f'/data/msd/audio/attributes/{name}.attributes.csv', schema=metadata_schema)

    schema_simple = StructType([
        StructField(f"F{i:03d}", DoubleType(), True) for i in range(0, metadata.count() - 1)
    ] + [
        StructField(f"ID", StringType(), True)
    ])

    data_simple = spark.read.csv(f'/data/msd/audio/features/{name}.csv', schema=schema_simple, quote="'")
    
    print(f"{name:42s} = ({data_simple.count():d}, {len(data_simple.columns) - 1})")
# Out:
# msd-jmir-area-of-moments-all-v1.0          = (994623, 20)
# msd-jmir-lpc-all-v1.0                      = (994623, 20)
# msd-jmir-methods-of-moments-all-v1.0       = (994623, 10)
# msd-jmir-mfcc-all-v1.0                     = (994623, 26)
# msd-jmir-spectral-all-all-v1.0             = (994623, 16)
# msd-jmir-spectral-derivatives-all-all-v1.0 = (994623, 16)
# msd-marsyas-timbral-v1.0                   = (995001, 124)
# msd-mvd-v1.0                               = (994188, 420)
# msd-rh-v1.0                                = (994188, 60)
# msd-rp-v1.0                                = (994188, 1440)
# msd-ssd-v1.0                               = (994188, 168)
# msd-trh-v1.0                               = (994188, 420)
# msd-tssd-v1.0                              = (994188, 1176)

# %%
# Run this cell before closing the notebook or kill your spark application by hand using the link in the Spark UI

stop_spark()
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>uwi14 (jupyter)</code> is under the completed applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li></ul>
